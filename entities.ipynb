# %%
import spacy
import random
import spacy.cli

# %%
TRAIN_DATA = [("Noida Area, India ",{"entities":[(0,17,"Work Exp")]}),
("April 2012 - January 2014 (1 year 10 months) ",{"entities":[(0,44,"Work Exp")]}),
("Project Manager ",{"entities":[(0,15,"Work Exp")]}),
("TBS ",{"entities":[(0,3,"Work Exp")]}),
("revenue. Developed brand strategy and statistics systems: ",{"entities":[(0,57,"Work Exp")]}),
("Brand development; web site traffic growth; web site Ul and advertising ",{"entities":[(0,71,"Work Exp")]}),
("Technical consultation and Execution. ",{"entities":[(0,37,"Work Exp")]}),
("Software Architect Design, Development; Web programming, Strategic and ",{"entities":[(0,70,"Work Exp")]}),
("Present (7 years 11 months) ",{"entities":[(0,27,"Work Exp")]}),
("January 2014 ",{"entities":[(0,12,"Work Exp")]}),
("Director ",{"entities":[(0,8,"Work Exp")]}),
("Enthuons Technologies Pvt: ",{"entities":[(0,26,"Work Exp")]}),
("Noida, Uttar Pradesh, India ",{"entities":[(0,27,"Work Exp")]}),
("Present (2 months) ",{"entities":[(0,18,"Work Exp")]}),
("October 2021 ",{"entities":[(0,12,"Work Exp")]}),
("Chief Executive Officer ",{"entities":[(0,23,"Work Exp")]}),
("CredoTree ",{"entities":[(0,9,"Work Exp")]}),
("Experience ",{"entities":[(0,10,"Work Exp")]}),
("Solution ",{"entities":[]}),
("MongoDB, AWS, RDS, Elastic Beanstalk; GIT , SVN, eCommerce ",{"entities":[(0,7,"Skills"),(9,12,"Skills"),(14,17,"Skills"),(19,36,"Skills"),(38,42,"Skills"),(44,47,"Skills"),(49,58,"Skills")]}),
("Codelgniter; WordPress, Drupal, Python, Core PHP , Mysql; ",{"entities":[(0,11,"Skills"),(13,22,"Skills"),(24,30,"Skills"),(32,38,"Skills"),(40,48,"Skills"),(51,56,"Skills")]}),
("Android development; Web Development; node:js, Laravel, ",{"entities":[(0,19,"Skills"),(21,36,"Skills"),(38,45,"Skills"),(47,54,"Skills")]}),
("Keywords: Digital Marketing Solution, Mobile App, iOS Development; ",{"entities":[(10,36,"Projects")]}),
("English ",{"entities":[(0,7,"Languages")]}),
("Languages ",{"entities":[(0,9,"Languages")]}),
("strategy starting with MVP. ",{"entities":[(0,26,"Achievements")]}),
("to end launch ",{"entities":[(0,13,"Achievements")]}),
("to client: He has rich experience assisting clients in framing an end ",{"entities":[(0,69,"Achievements")]}),
("jQuery ",{"entities":[(0,6,"Skills")]}),
("providing consultancy and suggesting an appropriate tech solutions ",{"entities":[(0,66,"Achievements")]}),
("JavaScript ",{"entities":[(0,10,"Skills")]}),
("solutions to innovative startups and enterprises He has interest in ",{"entities":[(0,67,"Achievements")]}),
("AJAX ",{"entities":[(0,4,"Skills")]}),
("Rohit is tech consultant involved in providing digital marketing ",{"entities":[(0,64,"Achievements")]}),
("Top Skils ",{"entities":[]}),
("Summary ",{"entities":[]}),
("0-0940a118 (Linkedln) ",{"entities":[(0,21,"Links")]}),
("www.linkedin comlinlrohit-bansal- ",{"entities":[(0,33,"Links")]}),
("Delhi ",{"entities":[(0,5,"Address")]}),
("Solving pain points of recruiters and recruitment processes. ",{"entities":[(0,60,"Other Deatils")]}),
("rohitbansalzoog@gmail.com ",{"entities":[(0,25,"Email")]}),
("9711357476 (Mobile) ",{"entities":[(0,10,"Contact")]}),
("Rohit Bansal ",{"entities":[(0,12,"Name")]}),
("Contact ",{"entities":[(0,7,"Contact")]}),
("12th, Physics . (2002 - 2003) ",{"entities":[(0,29,"Education")]}),
("DAV Inter college ",{"entities":[(0,17,"Education")]}),
("2010) ",{"entities":[(0,5,"Education")]}),
("MCA, computers . (2007 ",{"entities":[(0,22,"Education")]}),
("GCET ",{"entities":[(0,4,"Education")]}),
("Education ",{"entities":[(0,9,"Education")]}),
("web developer ",{"entities":[(0,13,"Work Exp")]}),
("August 2010 - June 2011 (11 months) ",{"entities":[(0,35,"Work Exp")]}),
("Employee ",{"entities":[(0,8,"Work Exp")]}),
("Successive Softwares ",{"entities":[(0,20,"Work Exp")]}),
("April 2012 (1 year) ",{"entities":[(0,19,"Work Exp")]}),
("May 2011 ",{"entities":[(0,8,"Work Exp")]}),
("Software Engineer ",{"entities":[(0,17,"Work Exp")]}),
("Tekriti Software ",{"entities":[(0,16,"Work Exp")]}),
("274401 ",{"entities":[(0,6,"Address")]}),
("Dist: - Kushinager U.P. ",{"entities":[(0,23,"Address")]}),
("Vil - Pachrukhiya, Post - Shankarpatkhauli, ",{"entities":[(0,43,"Address")]}),
("Permanent Address ",{"entities":[(0,17,"Address")]}),
("1Oth July 1995 ",{"entities":[(0,14,"DOB")]}),
("Date of Birth ",{"entities":[(0,13,"DOB")]}),
("Sunil Kumar Singh ",{"entities":[(0,17,"Name")]}),
("Name ",{"entities":[]}),
("PERSONAL DETAILS: ",{"entities":[]}),
("Listening songs. ",{"entities":[(0,15,"Other Deatils")]}),
("Playing and watching Cricket: ",{"entities":[(0,28,"Other Deatils")]}),
("HOBBIES: ",{"entities":[(0,7,"Other Deatils")]}),
("Hard working: ",{"entities":[(0,12,"Other Deatils")]}),
("Adaptability: ",{"entities":[(0,12,"Other Deatils")]}),
("Good Learner. ",{"entities":[(0,13,"Other Deatils")]}),
("Good Communication Skills. ",{"entities":[(0,25,"Other Deatils")]}),
("STRENGTHS: ",{"entities":[(0,9,"Other Deatils")]}),
("both functionality suppression like different color: ",{"entities":[(0,52,"Projects")]}),
("like excel sheet bulk uploads data and audio recording uploads, downloads ",{"entities":[(0,73,"Projects")]}),
("All functionality totaly handle this project multiple user access authority, ",{"entities":[(0,76,"Projects")]}),
("CRM Project (codeigniter framework) ",{"entities":[(0,35,"Projects")]}),
("category subcategory childcategory new post and multi feature functionality ",{"entities":[(0,75,"Projects")]}),
("AIl functionality totally handle this project like ecommerce add product listing add product ",{"entities":[(0,92,"Projects")]}),
("http IIcitymartsupermarketcom (codeigniter framework) ",{"entities":[(9,55,"Projects")]}),
("KEY PROJECT HANDLE ",{"entities":[(0,18,"Projects")]}),
("Amj Technologies Pvt: Ltd. (Jan' 2017 _ May' 2017) ",{"entities":[(0,50,"Work Exp")]}),
("PHP Developer ",{"entities":[(0,13,"Work Exp")]}),
("Leading Dots Solution Pvt: Ltd. (Aug'2017 - Jan'2018) ",{"entities":[(0,53,"Work Exp")]}),
("PHP Developer ",{"entities":[(0,13,"Work Exp")]}),
("SSR TECHVISION Pvt: Ltd. (Feb'2018 - Present) ",{"entities":[(0,45,"Work Exp")]}),
("PHP Developer ",{"entities":[(0,13,"Work Exp")]}),
("EXPERIENCE: ",{"entities":[(0,11,"Work Exp")]}),
("CSS ",{"entities":[(0,3,"Skills")]}),
("HTML ",{"entities":[(0,4,"Skills")]}),
("Javascript ",{"entities":[(0,10,"Skills")]}),
("Ajax ",{"entities":[(0,4,"Skills")]}),
("Jquery ",{"entities":[(0,6,"Skills")]}),
("OOPs ",{"entities":[(0,4,"Skills")]}),
("Codeigniter ",{"entities":[(0,11,"Skills")]}),
("Wordpress ",{"entities":[(0,9,"Skills")]}),
("Mysql ",{"entities":[(0,5,"Skills")]}),
("PHP ",{"entities":[(0,3,"Skills")]}),
("TECHNICAL QUALIFICATION: ",{"entities":[(0,24,"Skills")]}),
("2011 ",{"entities":[(0,4,"Education")]}),
("59.3 % ",{"entities":[(0,6,"Education")]}),
("U.P. BOARD ",{"entities":[(0,10,"Education")]}),
("High School ",{"entities":[(0,11,"Education")]}),
("2013 ",{"entities":[(0,4,"Education")]}),
("65.5% ",{"entities":[(0,5,"Education")]}),
("U.P. BOARD ",{"entities":[(0,10,"Education")]}),
("Intermediate ",{"entities":[]}),
("University ",{"entities":[(0,10,"Education")]}),
("2013-2016 ",{"entities":[(0,9,"Education")]}),
("60.33 % ",{"entities":[(0,7,"Education")]}),
("Makhanlal Chaturvedi ",{"entities":[(0,20,"Education")]}),
("B: C. A_ ",{"entities":[(0,8,"Education")]}),
("YEAR ",{"entities":[]}),
("PERCENTAGE ",{"entities":[]}),
("BOARD/UNIVERSITY ",{"entities":[]}),
("EXAMINATION ",{"entities":[]}),
("QUALIFICATIONS: ",{"entities":[(0,15,"Achievements")]}),
("position where | can effectively contribute my skills as a Software Professional: ",{"entities":[(0,81,"Other Deatils")]}),
("want to utilize my skils and potential to achieve a challenging position. Secure a chalenging ",{"entities":[(0,93,"Other Deatils")]}),
("CAREER OBJECTIVE: ",{"entities":[(0,17,"Other Deatils")]}),
("Contact Number: +91-8130070681 ",{"entities":[(16,30,"Contact")]}),
("E-mail ID: sunilsingh602095@gmail.com ",{"entities":[(11,37,"Email")]}),
("BCA) ",{"entities":[(0,4,"Education")]}),
("(Bachelor of Computer Applications ",{"entities":[(0,34,"Education")]}),
("Sunil Kumar Singh ",{"entities":[(0,17,"Name")]}),
("Sweetritiko1@gmail.com ",{"entities":[(0,22,"Email")]}),
("CLICK OR SCAN FOR PORTFOLIO ",{"entities":[]}),
("Ritik-sharma-78413a161 ",{"entities":[(0,22,"Links")]}),
("in ",{"entities":[]}),
("READING ",{"entities":[(0,7,"Other Deatils")]}),
("TRAVELLING ",{"entities":[(0,10,"Other Deatils")]}),
("MUSIC ",{"entities":[(0,5,"Other Deatils")]}),
("PHOTOGRAPHY ",{"entities":[(0,11,"Other Deatils")]}),
("COMMUNICATION ",{"entities":[(0,13,"Other Deatils")]}),
("ART DIRECTION ",{"entities":[(0,13,"Other Deatils")]}),
("TEAM WORK ",{"entities":[(0,9,"Other Deatils")]}),
("INNOVATION ",{"entities":[(0,10,"Other Deatils")]}),
("HOBBIES ",{"entities":[(0,7,"Other Deatils")]}),
("CONCEPTS ",{"entities":[(0,8,"Skills")]}),
("CREATIVE ",{"entities":[(0,8,"Skills")]}),
("GOOGLE ADS ",{"entities":[(0,10,"Skills")]}),
("E-MAILERS ",{"entities":[(0,9,"Skills")]}),
("BRANDING ",{"entities":[(0,8,"Skills")]}),
("SOCIAL MEDIA ",{"entities":[(0,12,"Skills")]}),
("MICROSOFT OFFICE ",{"entities":[(0,16,"Skills")]}),
("BRIDGE ",{"entities":[(0,6,"Skills")]}),
("VIDEO EDITING ",{"entities":[(0,13,"Skills")]}),
("2D VIDEOS ",{"entities":[(0,9,"Skills")]}),
("FILMORA ",{"entities":[(0,7,"Skills")]}),
("FIGMA ",{"entities":[(0,5,"Skills")]}),
("SKILLS ",{"entities":[(0,6,"Skills")]}),
("ADOBE XD ",{"entities":[(0,8,"Skills")]}),
("INDESIGN ",{"entities":[(0,8,"Skills")]}),
("202001 ",{"entities":[(0,6,"Address")]}),
("Goolar Road, Aligarh ",{"entities":[(0,20,"Address")]}),
("Shanti Sadan, Street No. 1 ",{"entities":[(0,26,"Address")]}),
("Address ",{"entities":[(0,7,"Address")]}),
("+91- 8273816476 ",{"entities":[(0,15,"Contact")]}),
("AUTOCAD ",{"entities":[(0,7,"Skills")]}),
("ILLUSTRATOR ",{"entities":[(0,11,"Skills")]}),
("+91-7906018545 ",{"entities":[(0,14,"Contact")]}),
("Contact ",{"entities":[(0,7,"Contact")]}),
("English, Hindi ",{"entities":[(9,14,"Languages"),(0,7,"Languages")]}),
("Languages ",{"entities":[(0,9,"Languages")]}),
("COREL DRAW ",{"entities":[(0,10,"Skills")]}),
("PHOTOSHOP ",{"entities":[(0,9,"Skills")]}),
("Indian ",{"entities":[(0,6,"Nationality")]}),
("Nationality ",{"entities":[(0,11,"Nationality")]}),
("Single ",{"entities":[(0,6,"Status")]}),
("Relationship ",{"entities":[(0,12,"Status")]}),
("SOFTWARE ",{"entities":[(0,8,"Skills")]}),
("June 7,1998 ",{"entities":[(0,11,"DOB")]}),
("Birthday ",{"entities":[(0,8,"DOB")]}),
("PERSONAL ",{"entities":[(0,8,"Other Deatils")]}),
("Graphic Designer ",{"entities":[(0,16,"Work Exp")]}),
("I/ April 2016 ",{"entities":[(0,13,"Projects")]}),
("Uppal Packagings ",{"entities":[(0,16,"Projects")]}),
("technical expretise can be fully utilized: ",{"entities":[]}),
("learning enviornment where my knowledge and ",{"entities":[]}),
("addition to conductive work culture and continuous ",{"entities":[(0,50,"Work Exp")]}),
("Senior Graphic Designer ",{"entities":[(0,23,"Work Exp")]}),
("responsible challenging and creative work profile in ",{"entities":[]}),
("design solution To with an organization that offers ",{"entities":[]}),
("I/ January 2018 ",{"entities":[(0,15,"Work Exp")]}),
("Creative Eye ",{"entities":[(0,12,"Achievements")]}),
("with a proven record of delevering creative and innovative ",{"entities":[(0,58,"Work Exp")]}),
("A highly talented driven flexible Graphic & UI/Ux Designer ",{"entities":[(0,58,"Work Exp")]}),
("Senior Graphic Designer ",{"entities":[(0,23,"Work Exp")]}),
("I/ March 2019 ",{"entities":[(0,13,"Work Exp")]}),
("CRE TECH: ",{"entities":[(0,9,"Work Exp")]}),
("PROFILE ",{"entities":[]}),
("EXPERIENCE ",{"entities":[(0,10,"Work Exp")]}),
("GRAPHIC & UIux DESIGNER ",{"entities":[(0,23,"Work Exp")]}),
("CBSE BOARD ",{"entities":[(0,10,"Education")]}),
("SHARMA ",{"entities":[(0,6,"Name")]}),
("Il2014 ",{"entities":[(0,6,"Education")]}),
("HIGHSCHOOL ",{"entities":[(0,10,"Education")]}),
("NIOS BOARD ",{"entities":[(0,10,"Education")]}),
("RITIK ",{"entities":[(0,5,"Name")]}),
("1/2017 ",{"entities":[]}),
("INTERMEDIATE ",{"entities":[]}),
("RELIANCE ANIMATION & VFX INSTITUTE INSTITUTE ",{"entities":[(0,44,"Work Exp")]}),
("1/2017 ",{"entities":[(0,6,"Education")]}),
("DIPLOMA IN GRAPHIC DESIGN ",{"entities":[(0,25,"Work Exp")]}),
("CAD DESK ",{"entities":[(0,8,"Skills")]}),
("1/2018 ",{"entities":[(0,6,"Education")]}),
("DIPLOMA IN AUTO CAD ",{"entities":[(0,19,"Education")]}),
("EDUCATION ",{"entities":[(0,9,"Education")]}),
("Hard Working: ",{"entities":[(0,13,"Other Deatils")]}),
("Team Spirit ",{"entities":[(0,11,"Other Deatils")]}),
("Positive Attitude ",{"entities":[]}),
("STRENGTHS ",{"entities":[]}),
("Good knowledge of computer;knowledge of Adobe photoshop, Adobe illustrator; corel draw: ",{"entities":[(40,45,"Skills"),(46,55,"Skills"),(57,74,"Skills"),(75,86,"Skills")]}),
("COMPUTER SKILLS ",{"entities":[(0,15,"Skills")]}),
("12th-passed with 65% from UP board in 2014 from Sanatan Dharm inter college. ",{"entities":[(0,76,"Education")]}),
("10th_ Passed with 70% from UP board in 2012 from Gautam public school. ",{"entities":[(0,70,"Education")]}),
("EDUCATIONAL QUALIFICATIONS ",{"entities":[(0,26,"Education")]}),
("experience graphic designer and pursing video editing ",{"entities":[(0,53,"Work Exp")]}),
("6 months ",{"entities":[(0,8,"Work Exp")]}),
("Education,Lucknow,Uttar Pradesh in 2018. And Currently pursing Digital game designing,and ",{"entities":[(0,89,"Education")]}),
("ffiliated by Board of Technical ",{"entities":[(0,31,"Education")]}),
("Technology Ghaziabad ",{"entities":[(0,20,"Education")]}),
("Saraswati Institute of Engineering ",{"entities":[(0,34,"Education")]}),
("3 Year Diploma in Mechanical Engineering (Production) with first division with 68.31% From ",{"entities":[]}),
("ROFESSIONAL QUALIFICATION ",{"entities":[]}),
("(Abdul Khan) ",{"entities":[]}),
("'Mumbai ",{"entities":[]}),
("Place ",{"entities":[]}),
("true and up to date to the best of my knowledge: ",{"entities":[]}),
("am Shubham tiwari declare with my full concern that all information mentioned above by me is ",{"entities":[]}),
("DECLARATION ",{"entities":[]}),
("Mumbai, Pin-222333. ",{"entities":[(0,18,"Address")]}),
("Mumbai, ",{"entities":[(0,7,"Address")]}),
("Distt: - ",{"entities":[(0,8,"Address")]}),
("Post: Gohda Bishunpura, ",{"entities":[(2,25,"Address")]}),
("Village:- Bishunpura, ",{"entities":[(0,21,"Address")]}),
("PERMANENT ADDRESS ",{"entities":[(0,17,"Address")]}),
("Muslim ",{"entities":[]}),
("Religion ",{"entities":[]}),
("Unmarried ",{"entities":[(0,9,"Status")]}),
("Marital Status ",{"entities":[(0,14,"Status")]}),
("Hindi, English: ",{"entities":[(7,14,"Languages"),(0,5,"Languages")]}),
("Language Known ",{"entities":[(0,14,"Languages")]}),
("Indian ",{"entities":[(0,6,"Nationality")]}),
("Nationality ",{"entities":[(0,11,"Nationality")]}),
("Male ",{"entities":[(0,4,"Gender")]}),
("Sex ",{"entities":[(0,3,"Gender")]}),
("18th January 1986 ",{"entities":[(0,17,"DOB")]}),
("Date of Birth ",{"entities":[(0,13,"DOB")]}),
("Abdul Khan ",{"entities":[(0,10,"Name")]}),
("Name ",{"entities":[(0,4,"Name")]}),
("PERSONAL INFORMATION ",{"entities":[(0,20,"Other Deatils")]}),
("Reading book ",{"entities":[]}),
("HOBBIES ",{"entities":[]}),
("draw.1 year experience in 2d autocad design Engineering and Solidworks. ",{"entities":[(0,71,"Work Exp")]}),
("experience in graphic designing software like Adobe photoshopAdobe illustrator; corel ",{"entities":[(0,85,"Work Exp")]}),
("6 months ",{"entities":[(0,8,"Work Exp")]}),
("1. ",{"entities":[]}),
("WORK EXPERIENCE ",{"entities":[(0,15,"Work Exp")]}),
(" ",{"entities":[]}),
("Gardening ",{"entities":[]}),
("Swimming ",{"entities":[]}),
("Cooking ",{"entities":[]}),
("Playing Dholak ",{"entities":[]}),
("Playing Keyboard ",{"entities":[]}),
("Playing Football and Chess ",{"entities":[]}),
("INTERESTS ",{"entities":[]}),
("opportunity: ",{"entities":[]}),
("Anchored in events in school and college: ",{"entities":[]}),
("Regularly took part in sports like chess and football when got ",{"entities":[]}),
("like debate, recitation, drama and etc ",{"entities":[]}),
("2019) ",{"entities":[]}),
("- ",{"entities":[]}),
("Sports (2013 _ ",{"entities":[]}),
("Participated and won in many cultural and social events ",{"entities":[]}),
("Features ",{"entities":[]}),
("playing keyboard, octapad and other instruments: ",{"entities":[]}),
("Represented school on regional and national level in exhibitions while ",{"entities":[]}),
("01/2010 - 2019 ",{"entities":[]}),
("Music (2013 - 2016) ",{"entities":[]}),
("Activities ",{"entities":[]}),
("MISCELLANEOUS ",{"entities":[]}),
("3. Event Participations ",{"entities":[]}),
("Chose prizes and trophies for the winners ",{"entities":[]}),
("Checkhere_ ",{"entities":[]}),
("handled the cash and budget for the event: ",{"entities":[]}),
("Greedy Algorithm: ",{"entities":[(0,16,"Skills")]}),
("Managed the negotiations with the event sponsors and ",{"entities":[]}),
("Blog writing for a code regarding Money exchange problem using ",{"entities":[]}),
("Features ",{"entities":[]}),
("Blogs regarding Greedy Algorithm (10/2021) ",{"entities":[]}),
("07/2019 - 09/2019 ",{"entities":[]}),
("College Events ",{"entities":[]}),
("Checkhere ",{"entities":[]}),
("application ",{"entities":[]}),
("2.Negotiator and Manager ",{"entities":[]}),
("Populating and saving data in Django database to be used in the ",{"entities":[]}),
("Django and Populating Database (09/2021) ",{"entities":[]}),
("and other cultural events_ ",{"entities":[]}),
("Coordinated and held events like debate, treasure hunt ",{"entities":[]}),
("Check My Blog: ",{"entities":[]}),
("and cultural Fest: ",{"entities":[]}),
("BLOG PUBLICATIONS ",{"entities":[]}),
("One ofthe four lead Coordinator for the annual technical ",{"entities":[]}),
("event in college. Got over 1000 views. ",{"entities":[]}),
("Developed the website For annual tech and cultural Fest ",{"entities":[]}),
("Features ",{"entities":[]}),
("Enthusiastic and Impulsive ",{"entities":[]}),
("06/2019 - 08/2019 ",{"entities":[]}),
("Annual College Event ",{"entities":[]}),
("Punctual ",{"entities":[]}),
("Anchor ",{"entities":[]}),
("Orator ",{"entities":[]}),
("Communnication ",{"entities":[(0,14,"Skills")]}),
("1. Developer and Lead Coordinator ",{"entities":[(3,33,"Achievements")]}),
("OTHER SKILLS ",{"entities":[(0,12,"Other Deatils")]}),
("ROLES AND RESPONSIBILITIES ",{"entities":[(0,26,"Achievements")]}),
("Indore, India ",{"entities":[(0,13,"Address")]}),
("Knowing the endgoal and pitching to achieve it: ",{"entities":[(0,47,"Other Deatils")]}),
("Student | Fresher ",{"entities":[(0,17,"Other Deatils")]}),
("+91 831-903-5085/722-393-1152 ",{"entities":[(0,29,"Contact")]}),
("sarvesh91199@gmailcom ",{"entities":[(0,21,"Email")]}),
("Sarvesh Dubey ",{"entities":[(0,13,"Name")]}),
("Code ",{"entities":[]}),
("Full Professional Proficiency ",{"entities":[]}),
("Full Professional Proficiency ",{"entities":[]}),
("Django Rest Framework project: ",{"entities":[(0,21,"Skills")]}),
("Hindi ",{"entities":[(0,5,"Languages")]}),
("English ",{"entities":[(0,7,"Languages")]}),
("Serving JWT verification and API testing via Postman in this ",{"entities":[(8,24,"Skills")]}),
("registration and login process_ ",{"entities":[]}),
("LANGUAGES ",{"entities":[(0,9,"Languages")]}),
("whom he is going to meet; while having to go through ",{"entities":[]}),
("User can book appointment and get the information from ",{"entities":[]}),
("An Admin-User Network for booking an appointment: ",{"entities":[]}),
("Coursera org ",{"entities":[]}),
("11/2022) ",{"entities":[]}),
("5. User-Admin Network (10/2021 ",{"entities":[(3,21,"Projects")]}),
("Crash Course on Pyhton ",{"entities":[(0,22,"Certificates")]}),
("Code ",{"entities":[]}),
("Internshala based training ",{"entities":[]}),
("the stocks and their price fluctuation every time we call the api ",{"entities":[(0,65,"Other Deatils")]}),
("Web Dev Training (05/2020 - 07/2020) ",{"entities":[(0,16,"Projects")]}),
("charts Using ApexCharts The charts gives information about ",{"entities":[(13,24,"Skills")]}),
("Receiving information an API and displaying that info in Form of ",{"entities":[(25,29,"Skills")]}),
("Coursera org ",{"entities":[]}),
("4. Django and Chartsjs (10/2021 - 10/2021) ",{"entities":[(3,22,"Projects")]}),
("Python to access Web Data (05/2020 - 06/2020) ",{"entities":[(0,25,"Certificates")]}),
("Working_Video ",{"entities":[]}),
("Coursera org ",{"entities":[]}),
("Code ",{"entities":[]}),
("machine learning code on the app. ",{"entities":[]}),
("Present) ",{"entities":[]}),
("Data Structures and Algorithms (10/2021 ",{"entities":[(20,30,"Skills"),(0,15,"Skills")]}),
("not by filling the form: Used pyhton Pickle library to deply the ",{"entities":[(0,64,"Other Deatils")]}),
("One can predict whether the person on titanic boat survived or ",{"entities":[(0,62,"Other Deatils")]}),
("CERTIFICATIONS ",{"entities":[(0,14,"Certificates")]}),
("MERN based web app to predict the survivor on titanic boat ",{"entities":[(0,5,"Skills")]}),
("3 . Titanic Survivors (10/2021) ",{"entities":[(4,31,"Projects")]}),
("Machine Learning ",{"entities":[(0,16,"Skills")]}),
("Code ",{"entities":[]}),
("Docker , Selenium , PostgreSQL , DigitalOcean , Heroku, ",{"entities":[(33,46,"Skills"),(20,31,"Skills"),(48,54,"Skills"),(9,18,"Skills"),(0,7,"Skills")]}),
("Used Spotify API to listen songs ",{"entities":[(0,32,"Other Deatils")]}),
("Admin can update the room information at any point: ",{"entities":[(0,51,"Other Deatils")]}),
("BeautifulSoup, Postman ",{"entities":[(15,22,"Skills"),(0,13,"Skills")]}),
("the admin, the song will automatically get skipped ",{"entities":[(0,50,"Other Deatils")]}),
("VS Code, Git, Github, MongoDB, Jupyter _ ",{"entities":[(31,39,"Skills"),(22,29,"Skills"),(14,20,"Skills"),(9,12,"Skills"),(0,7,"Skills")]}),
("vote to skip a song and if the votes reache Up to the mark set by ",{"entities":[(0,65,"Other Deatils")]}),
("Guests can play/pause song if Admin gives permissions and can ",{"entities":[(0,61,"Other Deatils")]}),
("TOOLS AND FAMILIAR WITH ",{"entities":[(0,23,"Other Deatils")]}),
("guests tojoin with a unique code For each room: ",{"entities":[(0,47,"Projects")]}),
("Minor Project Django-React based web app to create a room for ",{"entities":[(0,61,"Projects")]}),
("2. Party Room (04/2021 - 05/2021) ",{"entities":[(3,33,"Projects")]}),
("information with BS4 and Selenium ",{"entities":[(25,33,"Skills"),(17,21,"Skills")]}),
("Knowledge of parsing the htmlxml web pages and fetching required ",{"entities":[(0,64,"Other Deatils")]}),
("Herokuapp ",{"entities":[(0,9,"Skills")]}),
("Web Scraping ",{"entities":[(0,12,"Skills")]}),
("Code ",{"entities":[]}),
("77% of accuracy: ",{"entities":[(0,16,"Other Deatils")]}),
("the data in database For the prediction. Predict with more than ",{"entities":[(0,63,"Other Deatils")]}),
("Solving: ",{"entities":[]}),
("prediction of rainy weather by filling the form and the app uses ",{"entities":[(0,64,"Other Deatils")]}),
("Gold badge in Python and C/C++ and 3 stars and counting in Problem ",{"entities":[(0,66,"Other Deatils")]}),
("user on frontend while saving it in the database. User can make ",{"entities":[(0,63,"Projects")]}),
("Hacker Rank ",{"entities":[(0,11,"Achievements")]}),
("data from OpenWeatherMap.org API and returns the data to ",{"entities":[(0,56,"Projects")]}),
("retrieve live description of weather for a place. App Fetches ",{"entities":[(0,61,"Projects")]}),
("budget ,negotiations; prizes and other major things ",{"entities":[(0,51,"Achievements")]}),
("Django based web app to perform prediction of weather and ",{"entities":[(0,57,"Projects")]}),
("One of the few leading coordinator for the event and managed the ",{"entities":[(0,64,"Achievements")]}),
("1. Weather Prediction (10/2021) ",{"entities":[(3,31,"Projects")]}),
("Lead Coordinator (07/2019 - 08/2019) ",{"entities":[(0,36,"Achievements")]}),
("PERSONAL PROJECTS ",{"entities":[(0,17,"Projects")]}),
("cultural fest: Website get viewed by 1000+ candidates: ",{"entities":[(0,54,"Achievements")]}),
("Responsible for the development of website for annual technical and ",{"entities":[(0,67,"Achievements")]}),
("Website Developer (06/2019 - 08/2019) ",{"entities":[(0,37,"Achievements")]}),
("79.8% ",{"entities":[(0,5,"Education")]}),
("2015 - 2017 ",{"entities":[(0,11,"Education")]}),
("ACHIEVEMENT AND LEADERSHIP ",{"entities":[(0,26,"Achievements")]}),
("Kendriya Vidyalaya, Indore ",{"entities":[(0,26,"Education")]}),
("High School ",{"entities":[(0,11,"Education")]}),
("Reactjs ",{"entities":[(0,7,"Skills")]}),
("MERN ",{"entities":[(0,4,"Skills")]}),
("Flask ",{"entities":[(0,5,"Skills")]}),
("Django Rest Framework ",{"entities":[(0,21,"Skills")]}),
("Bhopal , 8.01 CGPA ",{"entities":[(0,18,"Education")]}),
("2018 - Present ",{"entities":[(0,14,"Education")]}),
("UIT, Barkatullah University ",{"entities":[(0,27,"Education")]}),
("Django ",{"entities":[(0,6,"Skills")]}),
("JavaScript ",{"entities":[(0,10,"Skills")]}),
("CIC++ ",{"entities":[(0,5,"Skills")]}),
("Pyhthon ",{"entities":[(0,7,"Skills")]}),
("B.E: in CSE ",{"entities":[(0,11,"Education")]}),
("SKILLS ",{"entities":[(0,6,"Skills")]}),
("EDUCATION ",{"entities":[(0,9,"Education")]}),
("github com/sarveshdubey ",{"entities":[(0,23,"Links")]}),
("linkedin com/in/sarvesh-dubey-407325171 in ",{"entities":[(2,44,"Links")]}),
("medium.com/@sarvesh_dubey ",{"entities":[(0,25,"Links")]}),
("Knowing the endgoal and pitching to achieve it ",{"entities":[(0,46,"Other Deatils")]}),
("Indore, India ",{"entities":[(0,13,"Address")]}),
("Student | Fresher ",{"entities":[(0,17,"Other Deatils")]}),
("722-393-1152 ",{"entities":[(0,12,"Contact")]}),
("+91 831-903-5085 ",{"entities":[(0,16,"Contact")]}),
("sarvesh91199@gmail.com ",{"entities":[(0,22,"Email")]}),
("Sarvesh Dubey ",{"entities":[(0,13,"Name")]}),
(" ",{"entities":[(0,13,"Name")]})]

# %%
nlp = spacy.blank('en')
ner = nlp.create_pipe("ner")

nlp.add_pipe(ner, last=True)

#ADD THE CUSTOM NAMED ENTITIES HERE
nlp.entity.add_label('Name')
nlp.entity.add_label('Email')
nlp.entity.add_label('Contact')
nlp.entity.add_label('Skills')
nlp.entity.add_label('Work Exp')
nlp.entity.add_label('Education')
nlp.entity.add_label('Address')
nlp.entity.add_label('Links')
nlp.entity.add_label('DOB')
nlp.entity.add_label('Staus')
nlp.entity.add_label('Nationality')
nlp.entity.add_label('Gender')
nlp.entity.add_label('Languages')
nlp.entity.add_label('Achievements')
nlp.entity.add_label('Fathers Name')
nlp.entity.add_label('Projects')
nlp.entity.add_label('Certificates')
nlp.entity.add_label('Other Deatils')
nlp.entity.add_label('Status')
nlp.entity.add_label('')


nlp.vocab.vectors.name = 'spacy_pretrained_vectors'
optimizer = nlp.begin_training()
for i in range(20):
    random.shuffle(TRAIN_DATA)
    for text, annotations in TRAIN_DATA:
        nlp.update([text], [annotations], sgd=optimizer)
#SAVE THE CUSTOM NER MODEL TO GOOGLE DRIVE
nlp.to_disk(r"C:\Users\Asus\OneDrive\Desktop\Practice Selenium\OCR and NER")
print("Model saved to drive")
# Out:
# C:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\spacy\language.py:635: UserWarning: [W033] Training a new parser or NER using a model with an empty lexeme normalization table. This may degrade the performance to some degree. If this is intentional or this language doesn't have a normalization table, please ignore this warning.
#   proc.begin_training(
# C:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\spacy\language.py:635: UserWarning: [W034] Please install the package spacy-lookups-data in order to include the default lexeme normalization table for the language 'en'.
#   proc.begin_training(
# ...

# %%
nlp2 = spacy.load(r"C:\Users\Asus\OneDrive\Desktop\Practice Selenium\OCR and NER")
with open('sar.txt','r') as f:
    lines = f.readlines()
data = ''.join(lines)    
    
doc2 = nlp2(data)
for ent in doc2.ents:
    print(ent.label_, " : ", ent.text_with_ws,,"\n")
# Out:
# Work Exp  :
#  CURRICULUM VITAE RUPESH THAKUR E-mail techrupesh22@gmailcom Contact No :+91-7021717010 CAREER OBJECTIVE To secure a responsible career opportunity to fuly utilize my training and skills, while making a significant contribution to the success of the company: ACADEMIC PROFILE STREAM NAME OF BOARD/ YEAR OF INSTITUTION UNIVERSITY PASSING S.S.C RK
# Skills  :
#  High School
# Work Exp  :
#  BSEB PATNA 2014 HS.C B.N.S.S.N
# Skills  :
#  INTER BSEB
# Other Deatils  :
#  , PATNA 2016 College Muzaffarpur, COPA S.J.Z Bhatia ITI Maharashtra Board 2019 BCA Sailee College YCMOU Nashik 2020 Borivali Mumbai TECHNICAL SKILLS
# Name  :
#  Framework Django
# Skills  :
#  Rest
# Skills  :
#  CSS
# Skills  :
#  JavaScript
# Skills  :
#  Bootstrap
# Skills  :
#  Database Software
# Skills  :
#  MySQL
# Skills  :
#  Software Git and GitHub
# Other Deatils  :
#  Pycharm Framework
# Skills  :
#  Core Java
